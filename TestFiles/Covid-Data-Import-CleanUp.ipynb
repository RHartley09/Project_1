# %%
import requests
import json
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
# Test dictionary made into DF
test = {"City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose"], "State": ["NY", "CA", "IL", "TX", "AZ", "PA", "TX", "CA", "TX", "CA"]}
test_df = pd.DataFrame(data=test)
test_df
# Out:
#            City State
# 0      New York    NY
# 1   Los Angeles    CA
# 2       Chicago    IL
# 3       Houston    TX
# 4       Phoenix    AZ
# 5  Philadelphia    PA
# 6   San Antonio    TX
# 7     San Diego    CA
# 8        Dallas    TX
# 9      San Jose    CA

# %%
# replace spaces with + to set up for API call 
test_df .replace(' ', '+',regex=True,inplace=True)
test_df
# Out:
#            City State
# 0      New+York    NY
# 1   Los+Angeles    CA
# 2       Chicago    IL
# 3       Houston    TX
# 4       Phoenix    AZ
# 5  Philadelphia    PA
# 6   San+Antonio    TX
# 7     San+Diego    CA
# 8        Dallas    TX
# 9      San+Jose    CA

# %%
# combine city and state data with fomatting for API call
test_df['var'] = test_df.agg('{0[City]}%2C+{0[State]}'.format, axis=1)
test_df
# Out:
#            City State                 var
# 0      New+York    NY      New+York%2C+NY
# 1   Los+Angeles    CA   Los+Angeles%2C+CA
# 2       Chicago    IL       Chicago%2C+IL
# 3       Houston    TX       Houston%2C+TX
# 4       Phoenix    AZ       Phoenix%2C+AZ
# 5  Philadelphia    PA  Philadelphia%2C+PA
# 6   San+Antonio    TX   San+Antonio%2C+TX
# 7     San+Diego    CA     San+Diego%2C+CA
# 8        Dallas    TX        Dallas%2C+TX
# 9      San+Jose    CA      San+Jose%2C+CA

# %%
# create a series from the 'var' column to loop through for API call 
var = pd.Series(test_df['var'])

# %%
# read in raw counties data 

# Cite - Wu, JieYing. “COVID-19 US County-Level Summaries.” Kaggle, 1 Apr. 2020, www.kaggle.com/jieyingwu/covid19-us-countylevel-summaries.

csv_path = "../raw_covid_data/DS-C-19-COUNTIES-1.csv"
cov_counties_1_df  = pd.read_csv(csv_path, encoding="utf-8")

# %%
cov_counties_1_df.head()
# Out:
#    FIPS State       Area_Name  Rural-urban_Continuum Code_2013  \
# 0     0    US   United States                              NaN
# 1  1000    AL         Alabama                              NaN
# 2  1001    AL  Autauga County                              2.0
# 3  1003    AL  Baldwin County                              3.0
# 4  1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2013  Economic_typology_2015  POP_ESTIMATE_2018  \
# 0                        NaN                     NaN          327167434
# 1                        NaN                     NaN            4887871
# 2                        2.0                     0.0              55601
# 3                        2.0                     5.0             218022
# 4                        6.0                     3.0              24881
#
#    N_POP_CHG_2018  Births_2018  Deaths_2018  ...  \
# 0       2020313.0    3855500.0    2814013.0  ...
# 1         12751.0      57216.0      53425.0  ...
# 2           158.0        655.0        532.0  ...
# 3          5403.0       2254.0       2228.0  ...
# 4          -277.0        261.0        324.0  ...
#
#    Total number of UCR (Uniform Crime Report) Index crimes excluding arson.  \
# 0                                                NaN
# 1                                                NaN
# 2                                              139.0
# 3                                              446.0
# 4                                               48.0
#
#    Total number of UCR (Uniform Crime Report) index crimes reported including arson  \
# 0                                                NaN
# 1                                                NaN
# 2                                             1765.0
# 3                                             4988.0
# 4                                              474.0
#
#    MURDER  RAPE  ROBBERY  Number of AGGRAVATED ASSAULTS  BURGLRY  LARCENY  \
# 0     NaN   NaN      NaN                            NaN      NaN      NaN
# 1     NaN   NaN      NaN                            NaN      NaN      NaN
# 2     3.0  15.0     34.0                           87.0    447.0   1233.0
# 3     8.0  30.0     76.0                          332.0    967.0   3829.0
# 4     0.0   4.0      8.0                           36.0     90.0    362.0
#
#    MOTOR VEHICLE THEFTS  ARSON
# 0                   NaN    NaN
# 1                   NaN    NaN
# 2                  85.0  108.0
# 3                 192.0   31.0
# 4                  21.0    0.0
#
# [5 rows x 347 columns]

# %%
# collect relevant column data
clean_county1_df = cov_counties_1_df[['Area_Name', 'State', 'POP_ESTIMATE_2018', 'Density per square mile of land area - Population', 'Unemployment_rate_2018', 'Median_Household_Income_2018', 'Total_Male', 'Total_Female', 'Total_age0to17', 'Male_age0to17', 'Female_age0to17', 'Total_age18to64', 'Male_age18to64', 'Female_age18to64', 'Total_age65plus', 'Male_age65plus', 'Female_age65plus', 'Total_age85plusr', 'Male_age85plusr', 'Female_age85plusr', 'ICU Beds', 'transit_scores - population weighted averages aggregated from town/city level to county']]
clean_county1_df.head()
# Out:
#         Area_Name State  POP_ESTIMATE_2018  \
# 0   United States    US          327167434
# 1         Alabama    AL            4887871
# 2  Autauga County    AL              55601
# 3  Baldwin County    AL             218022
# 4  Barbour County    AL              24881
#
#    Density per square mile of land area - Population  Unemployment_rate_2018  \
# 0                                               87.4                     3.9
# 1                                               94.4                     3.9
# 2                                               91.8                     3.6
# 3                                              114.6                     3.6
# 4                                               31.0                     5.2
#
#    Median_Household_Income_2018   Total_Male  Total_Female  Total_age0to17  \
# 0                       61937.0  161128679.0   166038755.0      73399342.0
# 1                       49881.0          NaN           NaN             NaN
# 2                       59338.0      26995.0       28606.0         13163.0
# 3                       57588.0     105657.0      112365.0         47110.0
# 4                       34382.0      13133.0       11748.0          5192.0
#
#    Male_age0to17  ...  Male_age18to64  Female_age18to64  Total_age65plus  \
# 0     37490849.0  ...     100331012.0       101005887.0       52431193.0
# 1            NaN  ...             NaN               NaN              NaN
# 2         6726.0  ...         16482.0           17303.0           8653.0
# 3        23810.0  ...         61166.0           65175.0          44571.0
# 4         2630.0  ...          8414.0            6443.0           4832.0
#
#    Male_age65plus  Female_age65plus  Total_age85plusr  Male_age85plusr  \
# 0      23306818.0        29124375.0         6544503.0        2325693.0
# 1             NaN               NaN               NaN              NaN
# 2          3787.0            4866.0             871.0            329.0
# 3         20681.0           23890.0            4304.0           1755.0
# 4          2089.0            2743.0             472.0            148.0
#
#    Female_age85plusr  ICU Beds  \
# 0          4218810.0       NaN
# 1                NaN       NaN
# 2              542.0       6.0
# 3             2549.0      51.0
# 4              324.0       5.0
#
#    transit_scores - population weighted averages aggregated from town/city level to county
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                        368329051.0
# 4                                                0.0
#
# [5 rows x 22 columns]

# %%
# rename columns
clean_county1_df.rename(columns={"Area_Name": "County",
                                 "POP_ESTIMATE_2018": "Population_2018",
                                 "Density per square mile of land area - Population": "Population_Density_Per_Square_Mile",
                                 "transit_scores - population weighted averages aggregated from town/city level to county": "Aggregate_Transit_Score",
                                 "ICU Beds": "ICU_Beds"
                                }, inplace=True)
clean_county1_df.head()
# Out:
# C:\Users\jakob\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            County State  Population_2018  Population_Density_Per_Square_Mile  \
# 0   United States    US        327167434                                87.4
# 1         Alabama    AL          4887871                                94.4
# 2  Autauga County    AL            55601                                91.8
# 3  Baldwin County    AL           218022                               114.6
# 4  Barbour County    AL            24881                                31.0
#
#    Unemployment_rate_2018  Median_Household_Income_2018   Total_Male  \
# 0                     3.9                       61937.0  161128679.0
# 1                     3.9                       49881.0          NaN
# 2                     3.6                       59338.0      26995.0
# 3                     3.6                       57588.0     105657.0
# 4                     5.2                       34382.0      13133.0
#
#    Total_Female  Total_age0to17  Male_age0to17  ...  Male_age18to64  \
# 0   166038755.0      73399342.0     37490849.0  ...     100331012.0
# 1           NaN             NaN            NaN  ...             NaN
# 2       28606.0         13163.0         6726.0  ...         16482.0
# 3      112365.0         47110.0        23810.0  ...         61166.0
# 4       11748.0          5192.0         2630.0  ...          8414.0
#
#    Female_age18to64  Total_age65plus  Male_age65plus  Female_age65plus  \
# 0       101005887.0       52431193.0      23306818.0        29124375.0
# 1               NaN              NaN             NaN               NaN
# 2           17303.0           8653.0          3787.0            4866.0
# 3           65175.0          44571.0         20681.0           23890.0
# 4            6443.0           4832.0          2089.0            2743.0
#
#    Total_age85plusr  Male_age85plusr  Female_age85plusr  ICU_Beds  \
# 0         6544503.0        2325693.0          4218810.0       NaN
# 1               NaN              NaN                NaN       NaN
# 2             871.0            329.0              542.0       6.0
# 3            4304.0           1755.0             2549.0      51.0
# 4             472.0            148.0              324.0       5.0
#
#    Aggregate_Transit_Score
# 0                      NaN
# 1                      NaN
# 2                      0.0
# 3              368329051.0
# 4                      0.0
#
# [5 rows x 22 columns]

# %%
# remove ' County' from County column string values for merging
clean_county1_df['County'].replace(' County', '', regex=True, inplace=True)
clean_county1_df.head()
# Out:
# C:\Users\jakob\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#           County State  Population_2018  Population_Density_Per_Square_Mile  \
# 0  United States    US        327167434                                87.4
# 1        Alabama    AL          4887871                                94.4
# 2        Autauga    AL            55601                                91.8
# 3        Baldwin    AL           218022                               114.6
# 4        Barbour    AL            24881                                31.0
#
#    Unemployment_rate_2018  Median_Household_Income_2018   Total_Male  \
# 0                     3.9                       61937.0  161128679.0
# 1                     3.9                       49881.0          NaN
# 2                     3.6                       59338.0      26995.0
# 3                     3.6                       57588.0     105657.0
# 4                     5.2                       34382.0      13133.0
#
#    Total_Female  Total_age0to17  Male_age0to17  ...  Male_age18to64  \
# 0   166038755.0      73399342.0     37490849.0  ...     100331012.0
# 1           NaN             NaN            NaN  ...             NaN
# 29  2020-01-30  Los Angeles  California   6037.0      1       0

# %%
# group by county and state, merge like instances of county and state and sum up cases and deaths for those unique values
cov_counties2_df = cov_counties_2_df.groupby(['county', 'state']).agg({'cases': 'sum', 'deaths': 'sum'})

# %%
# reset index to create DF
cov_counties2_df.reset_index()
# Out:
#          county           state  cases  deaths
# 0     Abbeville  South Carolina   1542       0
# 1        Acadia       Louisiana  10380     587
# 2      Accomack        Virginia  21017     303
# 3           Ada           Idaho  40601     930
# 4         Adair            Iowa    195       0
# ...         ...             ...    ...     ...
# 3007       Yuma         Arizona  13581     182
# 3008       Yuma        Colorado    564       0
# 3009     Zapata           Texas    351       0
# 3010     Zavala           Texas    229       0
# 3011    Ziebach    South Dakota     26       0
#
# [3012 rows x 4 columns]

# %%
# Rename index
cov_counties2_df.index = cov_counties2_df.index.set_names(['County', 'State'])
cov_counties2_df
# Out:
#                           cases  deaths
# County    State
# Abbeville South Carolina   1542       0
# Acadia    Louisiana       10380     587
# Accomack  Virginia        21017     303
# Ada       Idaho           40601     930
# Adair     Iowa              195       0
# ...                         ...     ...
# Yuma      Arizona         13581     182
#           Colorado          564       0
# Zapata    Texas             351       0
# Zavala    Texas             229       0
# Ziebach   South Dakota       26       0
#
# [3012 rows x 2 columns]

# %%
# reset the index
cov_counties2_df.reset_index(level=['County', 'State'], inplace=True)
cov_counties2_df
# Out:
#          County           State  cases  deaths
# 0     Abbeville  South Carolina   1542       0
# 1        Acadia       Louisiana  10380     587
# 2      Accomack        Virginia  21017     303
# 3           Ada           Idaho  40601     930
# 4         Adair            Iowa    195       0
# ...         ...             ...    ...     ...
# 3007       Yuma         Arizona  13581     182
# 3008       Yuma        Colorado    564       0
# 3009     Zapata           Texas    351       0
# 3010     Zavala           Texas    229       0
# 3011    Ziebach    South Dakota     26       0
#
# [3012 rows x 4 columns]

# %%
# use dictionary values to map and replace full state names in State column into state code for merging
us_state_abbrev = {
'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO',
'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID',
'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA',
'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD',
'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'}

cov_counties2_df['State'] = cov_counties2_df['State'].map(us_state_abbrev).fillna(cov_counties2_df['State'])
cov_counties2_df
# Out:
#          County State  cases  deaths
# 0     Abbeville    SC   1542       0
# 1        Acadia    LA  10380     587
# 2      Accomack    VA  21017     303
# 3           Ada    ID  40601     930
# 4         Adair    IA    195       0
# ...         ...   ...    ...     ...
# 3007       Yuma    AZ  13581     182
# 3008       Yuma    CO    564       0
# 3009     Zapata    TX    351       0
# 3010     Zavala    TX    229       0
# 3011    Ziebach    SD     26       0
#
# [3012 rows x 4 columns]

# %%
# export out as csv
cov_counties2_df.to_csv("../clean_data/county_data_2.csv", index=False, header=True)

# %%
csv_path = "../clean_data/county_data_2redo.csv"
cov_counties_2Redo_df  = pd.read_csv(csv_path, encoding="utf-8")

# %%
cov_counties_2Redo_df
# Out:
#         County State  cases  deaths
# 0      Unknown    OH      1       0
# 1      Unknown    MS      4       0
# 2      Unknown    IN      2       0
# 3      Unknown    PA      0       1
# 4      Unknown    SD      0       4
# ...        ...   ...    ...     ...
# 3007     Green    KY      1       0
# 3008   Greenup    KY     14       0
# 3009   Hancock    KY      8       0
# 3010  Franklin    KY     38       0
# 3011    Weston    WY      1       0
#
# [3012 rows x 4 columns]

# %%
# Merge two county DF's based on County and State columns
cov19_counties_merge_Redo = pd.merge(clean_county1_df, cov_counties_2Redo_df, how='outer', on=['County', 'State'])

cov19_counties_merge_Redo
# Out:
#                 County State  Population_2018  \
# 0        United States    US      327167434.0
# 1              Alabama    AL        4887871.0
# 2              Autauga    AL          55601.0
# 3              Baldwin    AL         218022.0
# 4              Barbour    AL          24881.0
# ...                ...   ...              ...
# 3382  East Baton Rouge    LA              NaN
# 3383      East Carroll    LA              NaN
# 3384    East Feliciana    LA              NaN
# 3385        Evangeline    LA              NaN
# 3386          Caldwell    LA              NaN
#
#       Population_Density_Per_Square_Mile  Unemployment_rate_2018  \
# 0                                   87.4                     3.9
# 1                                   94.4                     3.9
# 2                                   91.8                     3.6
# 3                                  114.6                     3.6
# 4                                   31.0                     5.2
# ...                                  ...                     ...
# 3382                                 NaN                     NaN
# 3383                                 NaN                     NaN
# 3384                                 NaN                     NaN
# 3385                                 NaN                     NaN
# 3386                                 NaN                     NaN
#
#       Median_Household_Income_2018   Total_Male  Total_Female  Total_age0to17  \
# 0                          61937.0  161128679.0   166038755.0      73399342.0
# 1                          49881.0          NaN           NaN             NaN
# 2                          59338.0      26995.0       28606.0         13163.0
# 3                          57588.0     105657.0      112365.0         47110.0
# 4                          34382.0      13133.0       11748.0          5192.0
# ...                            ...          ...           ...             ...
# 3382                           NaN          NaN           NaN             NaN
# 3383                           NaN          NaN           NaN             NaN
# 3384                           NaN          NaN           NaN             NaN
# 3385                           NaN          NaN           NaN             NaN
# 3386                           NaN          NaN           NaN             NaN
#
#       Male_age0to17  ...  Total_age65plus  Male_age65plus  Female_age65plus  \
# 0        37490849.0  ...       52431193.0      23306818.0        29124375.0
# 1               NaN  ...              NaN             NaN               NaN
# 2            6726.0  ...           8653.0          3787.0            4866.0
# 3           23810.0  ...          44571.0         20681.0           23890.0
# 4            2630.0  ...           4832.0          2089.0            2743.0
# ...             ...  ...              ...             ...               ...
# 3382            NaN  ...              NaN             NaN               NaN
# 3383            NaN  ...              NaN             NaN               NaN
# 3384            NaN  ...              NaN             NaN               NaN
# 3385            NaN  ...              NaN             NaN               NaN
# 3386            NaN  ...              NaN             NaN               NaN
#
#       Total_age85plusr  Male_age85plusr  Female_age85plusr  ICU_Beds  \
# 0            6544503.0        2325693.0          4218810.0       NaN
# 1                  NaN              NaN                NaN       NaN
# 2                871.0            329.0              542.0       6.0
# 3               4304.0           1755.0             2549.0      51.0
# 4                472.0            148.0              324.0       5.0
# ...                ...              ...                ...       ...
# 3382               NaN              NaN                NaN       NaN
# 3383               NaN              NaN                NaN       NaN
# 3384               NaN              NaN                NaN       NaN
# 3385               NaN              NaN                NaN       NaN
# 3386               NaN              NaN                NaN       NaN
#
#       Aggregate_Transit_Score   cases  deaths
# 0                         NaN     NaN     NaN
# 1                         NaN     NaN     NaN
# 2                         0.0   221.0     4.0
# 3                 368329051.0   290.0     9.0
# 4                         0.0   167.0     1.0
# ...                       ...     ...     ...
# 3382                      NaN  3618.0   239.0
# 3383                      NaN   148.0     0.0
# 3384                      NaN   194.0    30.0
# 3385                      NaN    78.0     1.0
# 3386                      NaN    54.0     0.0
#
# [3387 rows x 24 columns]

# %%
# drop any blank or NaN rows based on column 'Median_Household_Income_2018'
cov19_counties_merge_Redo = cov19_counties_merge_Redo.dropna(how='any', subset=['Median_Household_Income_2018'])
cov19_counties_merge_Redo
# Out:
#              County State  Population_2018  \
# 0     United States    US      327167434.0
# 1           Alabama    AL        4887871.0
# 2           Autauga    AL          55601.0
# 3           Baldwin    AL         218022.0
# 4           Barbour    AL          24881.0
# ...             ...   ...              ...
# 3189     Sweetwater    WY          43051.0
# 3190          Teton    WY          23081.0
# 3191          Uinta    WY          20299.0
# 3192       Washakie    WY           7885.0
# 3193         Weston    WY           6967.0
#
#       Population_Density_Per_Square_Mile  Unemployment_rate_2018  \
# 0                                   87.4                     3.9
# 1                                   94.4                     3.9
# 2                                   91.8                     3.6
# 3                                  114.6                     3.6
# 4                                   31.0                     5.2
# ...                                  ...                     ...
# 3189                                 4.2                     4.2
# 3190                                 5.3                     3.0
# 3191                                10.1                     4.4
# 3192                                 3.8                     4.2
# 3193                                 3.0                     3.5
#
#       Median_Household_Income_2018   Total_Male  Total_Female  Total_age0to17  \
# 0                          61937.0  161128679.0   166038755.0      73399342.0
# 1                          49881.0          NaN           NaN             NaN
# 2                          59338.0      26995.0       28606.0         13163.0
# 3                          57588.0     105657.0      112365.0         47110.0
# 4                          34382.0      13133.0       11748.0          5192.0
# ...                            ...          ...           ...             ...
# 3189                       73315.0      22152.0       20899.0         11290.0
# 3190                       99087.0      11909.0       11172.0          4239.0
# 3191                       63401.0      10285.0       10014.0          5844.0
# 3192                       55190.0       3988.0        3897.0          1793.0
# 3193                       54319.0       3689.0        3278.0          1447.0
#
#       Male_age0to17  ...  Total_age65plus  Male_age65plus  Female_age65plus  \
# 0        37490849.0  ...       52431193.0      23306818.0        29124375.0
# 1               NaN  ...              NaN             NaN               NaN
# 2            6726.0  ...           8653.0          3787.0            4866.0
# 3           23810.0  ...          44571.0         20681.0           23890.0
# 4            2630.0  ...           4832.0          2089.0            2743.0
# ...             ...  ...              ...             ...               ...
# 3189         5773.0  ...           5214.0          2546.0            2668.0
# 3190         2167.0  ...           3558.0          1796.0            1762.0
# 3191         3018.0  ...           2858.0          1417.0            1441.0
# 3192          912.0  ...           1710.0           828.0             882.0
# 3193          742.0  ...           1429.0           696.0             733.0
#
#       Total_age85plusr  Male_age85plusr  Female_age85plusr  ICU_Beds  \
# 0            6544503.0        2325693.0          4218810.0       NaN
# 1                  NaN              NaN                NaN       NaN
# 2                871.0            329.0              542.0       6.0
# 3               4304.0           1755.0             2549.0      51.0
# 4                472.0            148.0              324.0       5.0
# ...                ...              ...                ...       ...
# 3189             471.0            160.0              311.0      10.0
# 3190             325.0            132.0              193.0       6.0
# 3191             255.0             89.0              166.0       6.0
# 3192             242.0             97.0              145.0       0.0
# 3193             200.0             69.0              131.0       0.0
#
#       Aggregate_Transit_Score  cases  deaths
# 0                         NaN    NaN     NaN
# 1                         NaN    NaN     NaN
# 2                         0.0  221.0     4.0
# 3                 368329051.0  290.0     9.0
# 4                         0.0  167.0     1.0
# ...                       ...    ...     ...
# 3189                      0.0   30.0     0.0
# 3190                      0.0  100.0     1.0
# 3191              156203456.0   12.0     0.0
# 3192                      0.0   35.0     3.0
# 3193                      0.0    1.0     0.0
#
# [3193 rows x 24 columns]

# %%
# drop rows where there is no value for the column 'Total_Male'
cov19_counties_merge_Redo = cov19_counties_merge_Redo.dropna(subset = ['Total_Male'])
cov19_counties_merge_Redo
# Out:
#              County State  Population_2018  \
# 0     United States    US      327167434.0
# 2           Autauga    AL          55601.0
# 3           Baldwin    AL         218022.0
# 4           Barbour    AL          24881.0
# 5              Bibb    AL          22400.0
# ...             ...   ...              ...
# 3189     Sweetwater    WY          43051.0
# 3190          Teton    WY          23081.0
# 3191          Uinta    WY          20299.0
# 3192       Washakie    WY           7885.0
# 3193         Weston    WY           6967.0
#
#       Population_Density_Per_Square_Mile  Unemployment_rate_2018  \
# 0                                   87.4                     3.9
# 2                                   91.8                     3.6
# 3                                  114.6                     3.6
# 4                                   31.0                     5.2
# 5                                   36.8                     4.0
# ...                                  ...                     ...
# 3189                                 4.2                     4.2
# 3190                                 5.3                     3.0
# 3191                                10.1                     4.4
# 3192                                 3.8                     4.2
# 3193                                 3.0                     3.5
#
#       Median_Household_Income_2018   Total_Male  Total_Female  Total_age0to17  \
# 0                          61937.0  161128679.0   166038755.0      73399342.0
# 2                          59338.0      26995.0       28606.0         13163.0
# 3                          57588.0     105657.0      112365.0         47110.0
# 4                          34382.0      13133.0       11748.0          5192.0
# 5                          46064.0      11921.0       10479.0          4587.0
# ...                            ...          ...           ...             ...
# 3189                       73315.0      22152.0       20899.0         11290.0
# 3190                       99087.0      11909.0       11172.0          4239.0
# 3191                       63401.0      10285.0       10014.0          5844.0
# 3192                       55190.0       3988.0        3897.0          1793.0
# 3193                       54319.0       3689.0        3278.0          1447.0
#
#       Male_age0to17  ...  Total_age65plus  Male_age65plus  Female_age65plus  \
# 0        37490849.0  ...       52431193.0      23306818.0        29124375.0
# 2            6726.0  ...           8653.0          3787.0            4866.0
# 3           23810.0  ...          44571.0         20681.0           23890.0
# 4            2630.0  ...           4832.0          2089.0            2743.0
# 5            2399.0  ...           3690.0          1627.0            2063.0
# ...             ...  ...              ...             ...               ...
# 3189         5773.0  ...           5214.0          2546.0            2668.0
# 3190         2167.0  ...           3558.0          1796.0            1762.0
# 3191         3018.0  ...           2858.0          1417.0            1441.0
# 3192          912.0  ...           1710.0           828.0             882.0
# 3193          742.0  ...           1429.0           696.0             733.0
#
#       Total_age85plusr  Male_age85plusr  Female_age85plusr  ICU_Beds  \
# 0            6544503.0        2325693.0          4218810.0       NaN
# 2                871.0            329.0              542.0       6.0
# 3               4304.0           1755.0             2549.0      51.0
# 4                472.0            148.0              324.0       5.0
# 5                363.0            108.0              255.0       0.0
# ...                ...              ...                ...       ...
# 3189             471.0            160.0              311.0      10.0
# 3190             325.0            132.0              193.0       6.0
# 3191             255.0             89.0              166.0       6.0
# 3192             242.0             97.0              145.0       0.0
# 3193             200.0             69.0              131.0       0.0
#
#       Aggregate_Transit_Score  cases  deaths
# 0                         NaN    NaN     NaN
# 2                         0.0  221.0     4.0
# 3                 368329051.0  290.0     9.0
# 4                         0.0  167.0     1.0
# 5                 158361697.0   75.0     1.0
# ...                       ...    ...     ...
# 3189                      0.0   30.0     0.0
# 3190                      0.0  100.0     1.0
# 3191              156203456.0   12.0     0.0
# 3192                      0.0   35.0     3.0
# 3193                      0.0    1.0     0.0
#
# [3142 rows x 24 columns]

# %%
# export to csv
cov19_counties_merge_Redo.to_csv("../clean_data/county_data_merged.csv", index=False, header=True)

# %%
# imported raw data csv



csv_path = "../raw_covid_data/DS-C-19-STATES.csv"
cov_state_df= pd.read_csv(csv_path, encoding="utf-8")
cov_state_df.head()
# Out:
#         State   Tested  Infected  Deaths  Population  Pop Density    Gini  \
# 0      Alaska    36380       399      10      734002       1.2863  0.4081
# 1     Alabama   157566     12376     504     4908621      96.9221  0.4847
# 2    Arkansas    93701      4923     102     3038999      58.4030  0.4719
# 3     Arizona   220612     14566     704     7378494      64.9550  0.4713
# 4  California  1339316     81795    3334    39937489     256.3727  0.4899
#
#    ICU Beds  Income    GDP  ...  Hospitals  Health Spending  Pollution  \
# 0       119   59687  73205  ...         21            11064        6.4
# 1      1533   42334  45219  ...        101             7281        8.1
# 2       732   42566  42454  ...         88             7408        7.1
# 3      1559   43650  48055  ...         83             6452        9.7
# 4      7338   62586  74205  ...        359             7549       12.8
#
#    Med-Large Airports  Temperature  Urban  Age 0-25  Age 26-54  Age 55+  \
# 0         1900         21            11064      0.36       0.39     0.25
# 1        12205        101             7281      0.33       0.37     0.31
# 2         7150         88             7408      0.34       0.37     0.30
# 3        17806         83             6452      0.33       0.36     0.30
# 4       112906        359             7549      0.33       0.40     0.26
# 5        14509         89             6804      0.33       0.40     0.27
# 6        15605         32             9859      0.30       0.38     0.32
# 7         7346         10            11944      0.30       0.48     0.22
# 8         3148          7            10254      0.30       0.37     0.33
# 9        56499        217             8076      0.29       0.37     0.35
# 10       25312        145             6587      0.35       0.39     0.26
# 11        3660         22             7299      0.30       0.37     0.32
# 12        8511        118             8200      0.34       0.36     0.30
# 13        3012         45             6927      0.36       0.36     0.28
# 14       43377        187             8262      0.33       0.38     0.28
# 15       16816        132             8300      0.34       0.37     0.29
# 16        7926        139             7651      0.35       0.36     0.29
# 17       11937        105             8004      0.33       0.38     0.30
# 18       13821        158             7815      0.34       0.37     0.28
# 19       36506         75            10559      0.30       0.39     0.31
# 20       24676         50             8602      0.31       0.39     0.29
# 21        4721         34             9531      0.26       0.37     0.37
# 22       38819        144             8055      0.32       0.37     0.31
# 23       18171        127             8871      0.32       0.38     0.30
# 24       20275        122             8107      0.33       0.37     0.31
# 25        6597         99             7646      0.35       0.36     0.29
# 26        2326         56             8221      0.31       0.35     0.34
# 27       28379        112             7264      0.32       0.38     0.29
# 28        2015         39             9851      0.35       0.37     0.28
# 29        5627         93             8412      0.35       0.37     0.29
# 30        4240         28             9589      0.28       0.37     0.34
# 31       30502         82             8859      0.31       0.38     0.30
# 32        5830         41             7214      0.33       0.36     0.31
# 33        6151         44             6714      0.32       0.40     0.29
# 34       89500        166             9778      0.31       0.39     0.30
# 35       42373        194             8712      0.32       0.37     0.31
# 36        9472        125             7627      0.35       0.37     0.29
# 37       12149         61             8044      0.30       0.39     0.31
# 38       51069        199             9258      0.30       0.37     0.32
# 39        4988         11             9551      0.29       0.39     0.32
# 40       12847         69             7311      0.32       0.36     0.32
# 41        2041         57             8933      0.35       0.35     0.30
# 42       18979        115             7372      0.33       0.38     0.29
# 43       64602        523             6998      0.36       0.39     0.24
# 44        6761         54             5982      0.42       0.37     0.21
# 45       23307         96             7556      0.33       0.38     0.29
# 46        2338         14            10190      0.27       0.36     0.36
# 47       22036         92             7913      0.31       0.40     0.29
# 48       17695        133             8702      0.32       0.37     0.31
# 49        5685         56             9462      0.29       0.36     0.35
# 50        1172         29             8320      0.32       0.36     0.31
#
#    School Closure Date
# 0             03/19/20
# 1             03/16/20
# 2             03/17/20
# 3             03/16/20
# 4             03/19/20
# 5             03/23/20
# 6             03/17/20
# 7             03/16/20
# 8             03/16/20
# 9             03/16/20
# 10            03/18/20
# 11            03/23/20
# 12                 NaN
# 13            03/23/20
# 14            03/17/20
# 15            03/19/20
# 16            03/18/20
# 17            03/16/20
# 18            03/16/20
# 19            03/17/20
# 20            03/16/20
# 21                 NaN
# 22            03/16/20
# 23            03/18/20
# 24            03/19/20
# 25            03/20/20
# 26            03/16/20
# 27            03/16/20
# 28            03/16/20
# 29                 NaN
# 30            03/16/20
# 31            03/18/20
# 32            03/16/20
# 33            03/16/20
# 34            03/18/20
# 35            03/17/20
# 36            03/17/20
# 37            03/16/20
# 38            03/16/20
# 39            03/16/20
# 40            03/16/20
# 41            03/16/20
# 42            03/20/20
# 43            03/23/20
# 44            03/16/20
# 45            03/16/20
# 46            03/18/20
# 47            03/17/20
# 48            03/18/20
# 49            03/16/20
# 50            03/20/20

# %%
# replaced spaces with underscore
cov_state_df.columns = cov_state_df.columns.str.replace(' ', '_')
cov_state_df.head()
# Out:
#         State   Tested  Infected  Deaths  Population  Pop_Density  ICU_Beds  \
# 0      Alaska    36380       399      10      734002       1.2863       119
# 1     Alabama   157566     12376     504     4908621      96.9221      1533
# 2    Arkansas    93701      4923     102     3038999      58.4030       732
# 3     Arizona   220612     14566     704     7378494      64.9550      1559
# 4  California  1339316     81795    3334    39937489     256.3727      7338
#
#    Income    GDP  Unemployment  Flu_Deaths  Respiratory_Deaths  Physicians  \
# 0   59687  73205           5.8        12.1                35.3        1900
# 1   42334  45219           2.7        21.4                58.0       12205
# 2   42566  42454           3.5        18.0                61.7        7150
# 3   43650  48055           4.5        12.4                41.2       17806
# 4   62586  74205           3.9        15.6                30.9      112906
#
#    Hospitals  Health_Spending  Age_0-25  Age_26-54  Age_55+  \
# 0         21            11064      0.36       0.39     0.25
# 1        101             7281      0.33       0.37     0.31
# 2         88             7408      0.34       0.37     0.30
# 3         83             6452      0.33       0.36     0.30
# 4        359             7549      0.33       0.40     0.26
#
#   School_Closure_Date
# 0            03/19/20
# 1            03/16/20
# 2            03/17/20
# 3            03/16/20
# 4            03/19/20

# %%
# export to csv
cov_state_df.to_csv("../clean_data/state_data_1.csv", index=False, header=True)

# %%
# read in raw states data 
csv_path = "../raw_covid_data/DS-C-19-STATES-DAILY.csv"
cov_state2_df  = pd.read_csv(csv_path, encoding="utf-8")

# %%
cov_state2_df
# Out:
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200601    AK     467.0   53723.0      NaN                   10.0
# 1     20200601    AL   18363.0  205160.0      NaN                    NaN
# 2     20200601    AR    7443.0  125793.0      NaN                  115.0
# 3     20200601    AS       0.0     174.0      NaN                    NaN
# 4     20200601    AZ   20123.0  207947.0      NaN                  968.0
# ...        ...   ...       ...       ...      ...                    ...
# 4940  20200126    WA       1.0       NaN      NaN                    NaN
# 4941  20200125    WA       1.0       NaN      NaN                    NaN
# 4942  20200124    WA       1.0       NaN      NaN                    NaN
# 4943  20200123    WA       1.0       NaN      NaN                    NaN
# 4944  20200122    WA       1.0       NaN      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                        NaN             NaN              NaN
# 1                     1856.0             NaN            591.0
# 2                      711.0             NaN              NaN
# 3                        NaN             NaN              NaN
# 4                     3018.0           377.0              NaN
# ...                      ...             ...              ...
# 4940                     NaN             NaN              NaN
# 4941                     NaN             NaN              NaN
# 4942                     NaN             NaN              NaN
# 4943                     NaN             NaN              NaN
# 4944                     NaN             NaN              NaN
#
#       onVentilatorCurrently  ...  hospitalized   total totalTestResults  \
# 0                       1.0  ...           NaN   54190            54190
# 1                       NaN  ...        1856.0  223523           223523
# 2                      27.0  ...         711.0  133236           133236
# 3                       NaN  ...           NaN     174              174
# 4                     238.0  ...        3018.0  228070           228070
# ...                     ...  ...           ...     ...              ...
# 4940                    NaN  ...           NaN       1                1
# 4941                    NaN  ...           NaN       1                1
# 4942                    NaN  ...           NaN       1                1
# 4943                    NaN  ...           NaN       1                1
# 4944                    NaN  ...           NaN       1                1
#
#       posNeg fips deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0      54190    2           0.0                   0.0            2462.0
# 1     223523    1          15.0                  12.0            5510.0
# 2     133236    5           0.0                   0.0            3531.0
# 3        174   60           0.0                   0.0               0.0
# 4     228070    4          11.0                  20.0            2677.0
# ...      ...  ...           ...                   ...               ...
# 4940       1   53           0.0                   0.0               0.0
# 4941       1   53           0.0                   0.0               0.0
# 4942       1   53           0.0                   0.0               0.0
# 4943       1   53           0.0                   0.0               0.0
# 4944       1   53           NaN                   NaN               NaN
#
#       positiveIncrease  totalTestResultsIncrease
# 0                 33.0                    2495.0
# 1                460.0                    5970.0
# 2                190.0                    3721.0
# 3                  0.0                       0.0
# 4                187.0                    2864.0
# ...                ...                       ...
# 4940               0.0                       0.0
# 4941               0.0                       0.0
# 4942               0.0                       0.0
# 4943               0.0                       0.0
# 4944               NaN                       NaN
#
# [4945 rows x 27 columns]

# %%
# read in raw states data 
csv_path = "../clean_data/census_data.csv"
census_data  = pd.read_csv(csv_path, encoding="utf-8")

# %%
census_data
# Out:
#       Unnamed: 0         County State  Mean Household Income   Population  \
# 0              0     Washington    MS           30834.000000      47086.0
# 1              1          Perry    MS           39007.000000      12028.0
# 2              2        Choctaw    MS           37203.000000       8321.0
# 3              3       Itawamba    MS           40510.000000      23480.0
# 4              4        Carroll    MS           43060.000000      10129.0
# ...          ...            ...   ...                    ...          ...
# 3138        3216    Buena Vista    IA           54556.000000      20260.0
# 3139        3217        Guthrie    IA           57075.000000      10674.0
# 3140        3218       Humboldt    IA           52219.000000       9566.0
# 3141        3219     Washington    IA           61769.000000      22143.0
# 3142           0  United States    US           51583.175422  322903030.0
#
#       Median Age  Per Capita Income  Poverty Count  Unemployment Count
# 0      36.900000       19884.000000        15496.0              3041.0
# 1      40.900000       21611.000000         2231.0               337.0
# 2      44.000000       20589.000000         1888.0               301.0
# 3      40.000000       20629.000000         3428.0               414.0
# 4      47.000000       22567.000000         1477.0               377.0
# ...          ...                ...            ...                 ...
# 3138   35.200000       26607.000000         2507.0               590.0
# 3139   45.600000       28953.000000         1175.0               184.0
# 3140   43.000000       29882.000000         1103.0               180.0
# 3141   40.800000       29857.000000         2021.0               482.0
# 3142   41.288192       27036.489016     44246876.0           9507181.0
#
# [3143 rows x 9 columns]

# %%
# Merge census and combined county DF's based on County and State columns
census_county_merge = pd.merge(census_data, cov_counties_merge, how='outer', on=['County', 'State'])

census_county_merge
# Out:
#       Unnamed: 0                County State  Mean Household Income  \
# 0            0.0            Washington    MS           30834.000000
# 1            1.0                 Perry    MS           39007.000000
# 2            2.0               Choctaw    MS           37203.000000
# 3            3.0              Itawamba    MS           40510.000000
# 4            4.0               Carroll    MS           43060.000000
# ...          ...                   ...   ...                    ...
# 3140      3218.0              Humboldt    IA           52219.000000
# 3141      3219.0            Washington    IA           61769.000000
# 3142         0.0         United States    US           51583.175422
# 3143         NaN  District of Columbia    DC                    NaN
# 3144         NaN              Doña Ana    NM                    NaN
#
#        Population  Median Age  Per Capita Income  Poverty Count  \
# 0         47086.0   36.900000       19884.000000        15496.0
# 1         12028.0   40.900000       21611.000000         2231.0
# 2          8321.0   44.000000       20589.000000         1888.0
# 3         23480.0   40.000000       20629.000000         3428.0
# 4         10129.0   47.000000       22567.000000         1477.0
# ...           ...         ...                ...            ...
# 3140       9566.0   43.000000       29882.000000         1103.0
# 3141      22143.0   40.800000       29857.000000         2021.0
# 3142  322903030.0   41.288192       27036.489016     44246876.0
# 3143          NaN         NaN                NaN            NaN
# 3144          NaN         NaN                NaN            NaN
#
#       Unemployment Count  Population_2018  ...  Total_age65plus  \
# 0                 3041.0          45063.0  ...           7140.0
# 1                  337.0          11931.0  ...           2179.0
# 2                  301.0           8278.0  ...           1785.0
# 3                  414.0          23517.0  ...           4152.0
# 4                  377.0           9911.0  ...           2348.0
# ...                  ...              ...  ...              ...
# 3140               180.0           9547.0  ...           2055.0
# 3141               482.0          22141.0  ...           4272.0
# 3142           9507181.0      327167434.0  ...       52431193.0
# 3143                 NaN         702455.0  ...          85303.0
# 3144                 NaN         217522.0  ...          34338.0
#
#       Male_age65plus  Female_age65plus  Total_age85plusr  Male_age85plusr  \
# 0             2952.0            4188.0             740.0            201.0
# 1              970.0            1209.0             227.0             80.0
# 2              769.0            1016.0             203.0             72.0
# 3             1805.0            2347.0             481.0            169.0
# 4             1123.0            1225.0             244.0             94.0
# ...              ...               ...               ...              ...
# 3140           924.0            1131.0             354.0            121.0
# 3141          1889.0            2383.0             692.0            213.0
# 3142      23306818.0        29124375.0         6544503.0        2325693.0
# 3143         34838.0           50465.0           12153.0           4006.0
# 3144         15987.0           18351.0            4032.0           1684.0
#
#       Female_age85plusr  ICU_Beds  Aggregate_Transit_Score    cases  deaths
# 0                 539.0      22.0             0.000000e+00   5440.0   191.0
# 1                 147.0       0.0             0.000000e+00   1769.0    86.0
# 2                 131.0       0.0             0.000000e+00   1067.0    83.0
# 3                 312.0       0.0             0.000000e+00   2934.0   217.0
# 4                 150.0       0.0             0.000000e+00   3558.0   209.0
# ...                 ...       ...                      ...      ...     ...
# 3140              233.0       0.0             0.000000e+00    302.0     0.0
# 3141              479.0       0.0             0.000000e+00   8168.0   359.0
# 3142          4218810.0       NaN                      NaN      NaN     NaN
# 3143             8147.0     314.0             9.300000e+01      NaN     NaN
# 3144             2348.0      51.0             2.453145e+09  11623.0    83.0
#
# [3145 rows x 31 columns]

# %%
# export to csv
census_county_merge.to_csv("../clean_data/Combined_Census_Cov19.csv", index=False, header=True)
